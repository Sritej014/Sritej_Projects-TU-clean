# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Structure Unstructured Restaurant Data with an LLM**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## **Scenario**

# %% [markdown]
# ### Background
#
# You are a Data Engineer at a leading AI startup building a next-generation *Connoisseur Companion*. Unlike traditional recommendation systems that rely on coarse 1–5 star ratings, the organization aims to understand the **why** behind user preferences, capturing the vibe of a restaurant, dietary considerations, and standout **“hero dishes”** hidden inside unstructured, multimodal data.
#
# ### The challenge
#
# The organization has acquired a large, messy dataset spanning multiple modalities:
#
# * **Restaurant descriptions** and **user reviews** (raw TXT)
# * **Food recipes** with structured metadata and images (JSON + JPEG)
# * **User restaurant visit histories** (JSON with URLs)
#
# However, this data is not immediately usable:
#
# 1. **Unstructured text** lacks a consistent schema, making search and retrieval inefficient.
# 2. **Images and URLs** are opaque to traditional data pipelines and must be transformed into searchable, quantitative representations.
# 3. The data spans multiple modalities with no unified representation.
#
# To build a high-quality, explainable recommendation engine, your first task is to transform this **heterogeneous, multimodal data** into a **structured knowledge base**. This includes extracting semantic signals from **text**, generating representations for **images** and **URLs**, and organizing everything into a coherent, query-friendly JSON format.

# %% [markdown]
# ## **Objectives**

# %% [markdown]
# In this lab, you will write a Python program that will:
#
# * Load raw restaurant descriptions and review data from unstructured TXT files
# * Use a multimodal/LLM-based pipeline to extract structured attributes (e.g., cuisine type, ambiance, dietary options, and signature dishes)
# * Convert the extracted information into a well-defined JSON schema suitable for indexing and search

# %% [markdown]
# ## **Important: About the lab environment**

# %% [markdown]
# Please be aware that sessions for this lab environment are not persisted. Every time you connect to this lab, a new environment is created for you. Any data you may have saved in the earlier session would get lost. Plan to complete these labs in a single session, to avoid losing your data.

# %% [markdown]
# ## **Screenshot requirement for this lab**

# %% [markdown]
# You will be prompted to take a screenshot and save it on your own device. You will need this screenshot either to answer graded quiz questions or to upload as your submission for the Final Project at the end of this course. You can use various free screen-grabbing tools or your operating system's shortcut keys to do this (for example, `Alt+PrintScreen` on Windows and `Command+shift+4` on Mac).
#
# **Note**: The screenshot can be saved with either the **.jpg** or **.png** extension.

# %% [markdown]
# ----

# %% [markdown]
# ## **Set up the lab environment**

# %% [markdown]
# For this lab, you will be using the following libraries:
#
# * [`numpy`](https://numpy.org/) for numerical operations and handling array-based data during preprocessing and analysis
#
# * [`matplotlib`](https://matplotlib.org/) for basic data visualization and plotting, useful for inspecting distributions or intermediate results
#
# * [`json`](https://docs.python.org/3/library/json.html) for parsing, constructing, and serializing structured JSON representations extracted from unstructured text
#
# * **IBM Watsonx AI SDK** (`ibm-watsonx-ai`) for interacting with foundation models hosted on IBM watsonx.ai:
#
#   * `Credentials` to securely authenticate with the watsonx.ai service
#   * `ModelInference` to invoke foundation models for text understanding and information extraction
#   * `GenTextParamsMetaNames` to configure text generation and extraction parameters
#   * `ModelTypes` and `DecodingMethods` to select the appropriate model and control inference behavior
#
# These libraries together enable you to transform raw restaurant description text into structured, machine-readable knowledge using GenAI-powered workflows.

# %% [markdown]
# ### Install required libraries
#
# Run the following code block to install all required libraries:

# %%
# %%capture
# %pip install numpy==2.3.4
# %pip install matplotlib==3.10.7
# %pip install ibm-watsonx-ai==1.4.7

# %% [markdown]
# ### Import required libraries
#
# It is recommended to import all required libraries in one place (here):

# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import os

# IBM WatsonX imports
from ibm_watsonx_ai import Credentials
from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import (
    ModelTypes,
    DecodingMethods,
)

# Libraries and codes to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Fetch the data file

# %% [markdown]
# Run the following code to fetch the restaurant description text file:

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/1r_mM6ZPYNxcFv65QkzubA/California-Culinary-Map.txt
# Out:
# --2026-08-10 12:56:10--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/1r_mM6ZPYNxcFv65QkzubA/California-Culinary-Map.txt
# 169.63.118.104ourses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)...
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 74679 (73K) [text/plain]
# Saving to: ‘California-Culinary-Map.txt’
#
# California-Culinary 100%[===================>]  72.93K  --.-KB/s    in 0.01s
#
# 2026-08-10 12:56:11 (6.95 MB/s) - ‘California-Culinary-Map.txt’ saved [74679/74679]

# %% [markdown]
# ----

# %% [markdown]
# ## **Exercise 1: Load the data and display the texts**

# %% [markdown]
# Great! You now have the **California-Culinary-Map.txt** file in your folder. Before diving into the data, it is important to load and explore it first to gain a high-level understanding of its structure and content. This exercise gives you the opportunity to inspect the raw data and prepare it for transformation into a more structured, machine-accessible format.

# %% [markdown]
# ### Step 1: Load the data
#
# In Step 1, you will load the text data file and explore the restaurant contents. Make sure you use the correct file path that links to the file California-Culinary-Map.txt.

# %%
### Your Code Here:
### 1.1: Define the file_path to the text file
file_path =  "./California-Culinary-Map.txt"

### 1.2: Open the text file
with open(file_path, 'r') as file:
    data = file.read()

### 1.3: Print the first 100 characters of the restaurant data
print(data[:100])
# Out:
# ### The Culinary Map of California
#
# **The Gilded Artichoke** brings a **bohemian chic** energy to th

# %% [markdown]
# ### Step 2: Split the restaurant paragraphs into a Python list
#
# In the previous step, you may have noticed that the text file consists of multiple paragraphs, each describing a single restaurant. In Step 2, you will split these paragraphs into a list, allowing you to work with and manage each restaurant’s data more effectively.

# %%
### Your Code Here:
### 2.1: Split the restaurant paragraphs into list (hint: use .split('\n\n')
restaurant_list = data.split('\n\n')

### 2.2: Since the first item is the dataset name, we remove it
restaurant_list = restaurant_list[1:]

### 2.3: Print out the number of restaurants we have (hint: use the len() function)
print(len(restaurant_list))

### 2.4: Print out the first item to have a closer look at the content
print(restaurant_list[1])
# Out:
# 210
# Down in **Santa Monica**, **Mar de Cortez** serves as a **sun-drenched**, **casual taqueria** specializing in **Baja-style seafood**. With a **4.2/5** rating, it captures the salt-air energy of the coast through its signature beer-battered snapper tacos and zesty octopus ceviche, making it a premier spot for open-air dining near the pier. Price range: $

# %% [markdown]
# ----

# %% [markdown]
# ## **Exercise 2: Define the LLM**

# %% [markdown]
# You may have observed that each restaurant description includes the following key attributes:
# 1. Restaurant name
# 2. Location
# 3. Restaurant type
# 4. Food style
# 5. Rating
# 6. Price range
# 7. Signature dishes
# 8. Specialties
# 9. Shortcomings
#
# This information is essential for uniquely identifying and describing a restaurant.
#
# In this lab, you will use a large language model (LLM) to organize these attributes into a structured JSON format. As a first step, you will define the base LLM that will extract and structure the information from the unstructured text.

# %% [markdown]
# ### Step 1: Implement the LLM function

# %% [markdown]
# You will use **IBM Granite 4H Small** as the base LLM for this lab, as it provides strong text understanding capabilities while remaining cost-efficient:

# %%
def llm_model(system_msg, prompt_txt):
    #system_msg: the system message given to the LLM
    #prompt_txt: the user prompt
    
    model_id = "ibm/granite-4-h-small"

    project_id="skills-network"

    credentials = Credentials(
                    url = "https://us-south.ml.cloud.ibm.com"
                    )

    ### 1.1: Define the model by ModelInference
    model = ModelInference(
        model_id=model_id,
        credentials=credentials,
        project_id=project_id
    )

    ### 1.2: Define the messages
    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user", "content": prompt_txt}
    ]

    ### 1.3: Get the final response output and return it
    response = model.chat(messages=messages)
    output_text = response["choices"][0]["message"]["content"]
    
    return output_text

# %% [markdown]
# ### Step 2: Test your llm_model()

# %% [markdown]
# Test your LLM function with the following inputs:

# %%
import time

def safe_llm_call(system_msg, prompt_txt, retries=3):
    for i in range(retries):
        try:
            return llm_model(system_msg, prompt_txt)
        except Exception:
            time.sleep(2)
    return "Failed after retries"

# %%
system_msg = "You are a helpful assistant."
prompt_txt = "Which place is warmer in winter? Hawaii or Greenland?"
print(safe_llm_call(system_msg, prompt_txt))
# Out:
# Hawaii is much warmer in winter than Greenland.
#
# Hawaii, being a tropical region near the equator, has warm temperatures year-round. Even in winter (December-February), average temperatures in Hawaii typically range from the mid-60s to low 70s (around 18-23°C).
#
# Greenland, on the other hand, is an Arctic region far north of the equator. During winter months (December-February), temperatures in most of Greenland are well below freezing. Average temperatures often range from -20°C to -40°C (-4°F to -40°F), with colder temperatures near the inland ice cap.
#
# So in summary, Hawaii is significantly warmer than Greenland, especially during the winter months. The difference in climate is due to their very different latitudes and locations on the planet.

# %% [markdown]
# ----

# %% [markdown]
# ## **Exercise 3: Prompt Engineering**

# %% [markdown]
# To make an LLM behave reliably and produce outputs that meet your requirements, careful prompt design is essential. Here is a recap of key prompt engineering techniques:
#
# * **Clear and specific instructions**: Explicitly state the task, expected output format, and constraints to reduce ambiguity.
# * **Structured output guidance**: Provide schemas, templates, or examples (e.g., JSON formats) to encourage consistent, machine-readable responses.
# * **Few-shot prompting**: Include representative input–output examples to guide the model toward the desired behavior.
# * **Role prompting**: Assign the model a specific role (e.g., “You are a data extraction assistant”) to shape its reasoning and tone.
# * **Constraint-based prompting**: Define what the model should and should not do to improve precision and reliability.
# * **Iterative refinement**: Evaluate outputs and progressively refine prompts to improve performance over time.
#
# This exercise focuses on one-shot prompting, a special case of few-shot prompting. You will define a function that generates the prompt templates.

# %% [markdown]
# ### Step 1: Define the template

# %% [markdown]
# In **Step 1**, you will implement a function that generates prompts for the LLM, given an input restaurant description paragraph.
#
# You will apply the **one-shot prompting** technique, which includes a single example of the desired output within the prompt to guide the model’s response.
#
# An example output is provided, corresponding to the second restaurant paragraph in your `restaurant_list` variable. Using this example, you will design a prompt template that enables the model to consistently transform *any* input restaurant description into the required structured JSON format.
#
# **Note:** For the price range field, instruct the LLM to convert dollar signs (e.g., \\\\\\\\\\\\\\\\\\\\\\\\$, \\$\\$, $$$) into an integer representing the number of dollar symbols.

# %%
EXAMPLE_RESTAURANT_PARAGRAPH = restaurant_list[1] #use the second restaurant paragraph as the example
EXAMPLE_OUTPUT = """
    {{
    "name": "Mar de Cortez",
    "location": "Santa Monica",
    "type": "casual taqueria",
    "food_style": "Baja-style seafood",
    "rating": 4.2,
    "price_range": 1,
    "signatures": [
        "beer-battered snapper tacos",
        "zesty octopus ceviche"
    ],
    "vibe": "salt-air energy",
    "environment": "a premier sun-drenched spot for open-air dining near the pier.",
    "shortcomings": []
    }}
"""

### Design your prompt here
def restaurant_data_structure_prompt_generation(restaurant_paragraph):
    base_system_msg = f"""
    Unstructured text lacks a consistent schema, making search and retrieval inefficient{restaurant_paragraph}. 
    Convert the extracted information from {restaurant_paragraph} into a well-defined JSON schema suitable for 
    indexing and search. For the price range field, instruct the LLM to convert dollar signs (e.g., \\\\\\
$$) into an integer representing the number of dollar symbols.
Sample JSON Structured Output
    {{
    "name": "Mar de Cortez",
    "location": "Santa Monica",
    "type": "casual taqueria",
    "food_style": "Baja-style seafood",
    "rating": 4.2,
    "price_range": 1,
    "signatures": [
        "beer-battered snapper tacos",
        "zesty octopus ceviche"
    ],
    "vibe": "salt-air energy",
    "environment": "a premier sun-drenched spot for open-air dining near the pier.",
    "shortcomings": []
    }}
    """
    
    base_user_prompt = f"""
    Task:
    Convert the extracted information from {restaurant_paragraph} into a well-defined JSON schema suitable for 
    indexing and search. convert dollar signs (e.g., \\\\\\ $$) into an integer representing the number of dollar symbols.

    Restaurant description:
    {restaurant_paragraph}
    Down in **Santa Monica**, **Mar de Cortez** serves as a **sun-drenched**, 
    **casual taqueria** specializing in **Baja-style seafood**. With a **4.2/5** rating, 
    it captures the salt-air energy of the coast through its signature beer-battered snapper tacos 
    and zesty octopus ceviche, making it a premier spot for open-air dining near the pier. Price range: $

    Example:
    Input Restaurant Description: {EXAMPLE_RESTAURANT_PARAGRAPH}
    Output:
    {EXAMPLE_OUTPUT}
    
    """
    return base_system_msg, base_user_prompt

# %% [markdown]
# ### Step 2: Test your prompts

# %% [markdown]
# Run the following code to verify that your prompt produces the expected output:

# %%
# Unit test:
restaurant_paragraph = restaurant_list[0]
base_system_msg, base_user_prompt = restaurant_data_structure_prompt_generation(restaurant_paragraph=restaurant_paragraph)

test_response = llm_model(system_msg=base_system_msg, prompt_txt=base_user_prompt)
print(test_response)
# Out:
# {
#     "name": "The Gilded Artichoke",
#     "location": "Silver Lake",
#     "type": "upscale bistro",
#     "food_style": "Farm-to-Table Californian",
#     "rating": 4.5,
#     "price_range": 4,
#     "signatures": [
#         "lavender-rubbed roasted chicken",
#         "heirloom tomato tarts"
#     ],
#     "vibe": "bohemian chic",
#     "environment": "a high-end greenhouse with reclaimed wood and floor-to-ceiling windows",
#     "shortcomings": []
# }

# %% [markdown]
# ### Step 3: Validate the LLM outputs

# %% [markdown]
# LLMs are not always perfectly reliable and may produce errors, even when strict rules are specified in the prompt. To ensure that the generated outputs strictly conform to the required JSON format, you will learn how to define a function that formally validates the LLM output.
#
# Here, you are provided with the function and the test. You don't have to implement anything. Run the following code to validate the test response you obtained in Step 2.

# %%
# Validation
from pydantic import BaseModel, Field, ValidationError
from typing import List, Optional

### 3.1. Define the schema
class Restaurant(BaseModel):
    name: str
    location: str
    type: str
    food_style: str
    rating: Optional[float] = None
    price_range: Optional[int] = None
    signatures: List[str] = Field(default_factory=list)
    vibe: Optional[str] = None
    environment: str
    shortcomings: List[str] = Field(default_factory=list)


### 3.2. Use the validation method to validate the test_response from the unit test
try:
    restaurant_data = Restaurant.model_validate_json(test_response)
    print(f"Success! Validated: {restaurant_data.name}")
except ValidationError as e:
    print(f"Validation failed: {e.json()}")
# Out:
# Success! Validated: The Gilded Artichoke

# %% [markdown]
# Don't worry if your validation failed; we'll address that in the next exercise.

# %% [markdown]
# ----

# %% [markdown]
# ## **Exercise 4: Structure all the restaurant data**

# %% [markdown]
# ### Step 1: Define prompts to have an LLM that auto repairs outputs to JSON format

# %% [markdown]
# As mentioned earlier, LLMs are not perfect. While you previously defined a schema to validate the output, validation alone does not fix incorrect results. To address this, introduce an additional LLM “expert” whose sole responsibility is to automatically repair and correct outputs that do not conform to the required JSON format.
#
# In this step, you will define the prompt template function for this LLM. This function takes:
# - `candidate_json_output`: The candidate json output
# - `error_message`: The error message generated by the schema validation if a mistake is detected
#
# In your prompts, you should tell LLM:
# - The original wrong output by feeding `candidate_json_output`
# - The guidance on correction by feeding `error_message`

# %%
def JSON_auto_repair_prompts(candidate_json_output, error_message):

    auto_repair_system_msg = """
You are a JSON repair expert.

Your task is to correct invalid restaurant JSON so that it conforms
exactly to the required schema.

Return ONLY the corrected JSON object.

Do not include:
- explanations
- markdown
- ```json code fences
- comments
- text before or after the JSON
"""

    auto_repair_prompt = f"""
Correct the following invalid JSON.

Invalid JSON:
{candidate_json_output}

Validation error:
{error_message}

Required schema:

{{
    "name": "string",
    "location": "string",
    "type": "string",
    "food_style": "string",
    "rating": float or null,
    "price_range": integer or null,
    "signatures": ["string"],
    "vibe": "string or null",
    "environment": "string",
    "shortcomings": ["string"]
}}

Return ONLY valid JSON.
"""

    return auto_repair_system_msg, auto_repair_prompt

# %% [markdown]
# ### Step 2: Run the for loop to go over all the restaurant data in the list (approximately 20 minutes)

# %% [markdown]
# You will structure each restaurant description paragraph into a JSON-formatted output by iterating through the dataset using a for loop.
#
# Although using an LLM to auto repair the response format is not the best practice, here you are guaranteed that the generation and repair tasks here are simple enough for LLMs to accomplish.

# %%
structured_restaurant_lists = []
for i, restaurant_paragraph in enumerate(restaurant_list):
    ### 2.1: Produce your initial output
    print("LLM Output Initiated....................................................")
    base_system_msg, base_user_prompt = (restaurant_data_structure_prompt_generation(restaurant_paragraph=restaurant_paragraph))
    candidate_json_output = llm_model(system_msg=base_system_msg, prompt_txt=base_user_prompt)

    print("LLM Output done....................................................")
    while True:
        try:
            print("Entered Try....................................................")
            Restaurant.model_validate_json(candidate_json_output)
            print("Validated....................................................")
            break
        
        except ValidationError as e:
            print("Entered Except")
            
            print("\nVALIDATION ERROR:")
            print(e)
        
            print("\nINVALID OUTPUT:")
            print(candidate_json_output)
        
            repair_system_msg, repair_prompt = JSON_auto_repair_prompts(
                candidate_json_output,
                str(e)
            )
        
            candidate_json_output = llm_model(
                system_msg=repair_system_msg,
                prompt_txt=repair_prompt
            )

    print("\nREPAIRED OUTPUT:")
    print(candidate_json_output)
    print("Tryna Append....................................................")
    structured_restaurant_lists.append(candidate_json_output)
    print("Outa Append....................................................")
    if (i+1)%20 == 0:
        print(f'{i+1} out of {len(restaurant_list)} is done')

# A final message to notify the completion
print('ALL DONE!!')
# Out:
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here\'s the restaurant i...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here's the restaurant information converted into the specified JSON schema:
#
# {
#     "name": "The Gilded Artichoke",
#     "location": "Silver Lake",
#     "type": "upscale bistro",
#     "food_style": "Farm-to-Table Californian",
#     "rating": 4.5,
#     "price_range": 4,
#     "signatures": [
#         "lavender-rubbed roasted chicken",
#         "heirloom tomato tarts"
#     ],
#     "vibe": "bohemian chic",
#     "environment": "a high-end greenhouse with its reclaimed wood and floor-to-ceiling windows",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Gilded Artichoke",
#     "location": "Silver Lake",
#     "type": "upscale bistro",
#     "food_style": "Farm-to-Table Californian",
#     "rating": 4.5,
#     "price_range": 4,
#     "signatures": [
#         "lavender-rubbed roasted chicken",
#         "heirloom tomato tarts"
#     ],
#     "vibe": "bohemian chic",
#     "environment": "a high-end greenhouse with its reclaimed wood and floor-to-ceiling windows",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Mar de Cortez",
#     "location": "Santa Monica",
#     "type": "casual taqueria",
#     "food_style": "Baja-style seafood",
#     "rating": 4.2,
#     "price_range": 1,
#     "signatures": [
#         "beer-battered snapper tacos",
#         "zesty octopus ceviche"
#     ],
#     "vibe": "salt-air energy",
#     "environment": "a premier sun-drenched spot for open-air dining near the pier."
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Iron & Embers",
#     "location": "DTLA",
#     "neighbourhood": "Arts District",
#     "type": "fine dining",
#     "food_style": "industrial American steakhouse",
#     "rating": 4.8,
#     "price_range": 4,
#     "signature_dishes": [
#         "45-day dry-aged ribeye",
#         "bone marrow chimichurri"
#     ],
#     "vibe": "moody",
#     "environment": "industrial space with white oak smoke and masculine sophistication",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected `,` or `}` at line 13 column 5 [type=json_invalid, input_value='{\n    "name": "Sakura G...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# {
#     "name": "Sakura Garden",
#     "location": "Little Tokyo",
#     "type": "Japanese Kaiseki-lite",
#     "food_style": "intimate",
#     "rating": 4.9,
#     "price_range": 3,
#     "signatures": [
#         "buttery bluefin tuna belly"
#     ],
#     "vibe": "zen and minimalist",
#     "environment": "a quiet escape focusing on seasonal perfection for serious sushi aficionados."
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Sakura Garden",
#     "location": "Little Tokyo",
#     "type": "Japanese Kaiseki-lite",
#     "food_style": "intimate",
#     "rating": 4.9,
#     "price_range": 3,
#     "signatures": [
#         "buttery bluefin tuna belly"
#     ],
#     "vibe": "zen and minimalist",
#     "environment": "a quiet escape focusing on seasonal perfection for serious sushi aficionados.",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
# food_style
#   Field required [type=missing, input_value={'name': 'Pasta & Prose',...ith vibrant atmosphere'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# INVALID OUTPUT:
# {
#   "name": "Pasta & Prose",
#   "location": "West Hollywood",
#   "type": "modern Italian trattoria",
#   "rating": 4.3,
#   "price_range": 3,
#   "ambience": "glamorous, lively, see-and-be-seen hub",
#   "signature_dishes": [
#     "chilled prosecco",
#     "table-side Cacio e Pepe with parmesan wheel"
#   ],
#   "environment": "Trendy West Hollywood restaurant with vibrant atmosphere"
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#   "name": "Pasta & Prose",
#   "location": "West Hollywood",
#   "type": "modern Italian trattoria",
#   "food_style": "modern Italian",
#   "rating": 4.3,
#   "price_range": 3,
#   "signatures": [
#     "chilled prosecco",
#     "table-side Cacio e Pepe with parmesan wheel"
#   ],
#   "vibe": "glamorous, lively, see-and-be-seen hub",
#   "environment": "Trendy West Hollywood restaurant with vibrant atmosphere",
#   "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the converted JS...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the converted JSON for the provided restaurant description:
#
# {
#     "name": "The Golden Hummus",
#     "location": "Glendale",
#     "type": "modern Lebanese eatery",
#     "food_style": "family-style",
#     "rating": 4.6,
#     "price_range": 2,
#     "signatures": [
#         "standout signature hummus topped with spiced wagyu beef"
#     ],
#     "vibe": "communal atmosphere",
#     "environment": "a bustling environment that makes every guest feel like part of a large, hungry family.",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Golden Hummus",
#     "location": "Glendale",
#     "type": "modern Lebanese eatery",
#     "food_style": "family-style",
#     "rating": 4.6,
#     "price_range": 2,
#     "signatures": [
#         "standout signature hummus topped with spiced wagyu beef"
#     ],
#     "vibe": "communal atmosphere",
#     "environment": "a bustling environment that makes every guest feel like part of a large, hungry family.",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Velvet & Vine",
#     "location": "Pasadena",
#     "type": "romantic wine bar",
#     "food_style": "French-Mediterranean small plates",
#     "rating": 4.1,
#     "price_range": 2,
#     "signatures": [
#         "duck confit sliders",
#         "small-batch European wine labels"
#     ],
#     "vibe": "sophisticated atmosphere",
#     "environment": "historic, exposed-brick setting",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Neon Noodle Bar",
#     "location": "San Gabriel Valley",
#     "type": "fast-casual Sichuan street food",
#     "food_style": "numbing Dan Dan noodles and cumin lamb skewers",
#     "rating": 4.4,
#     "price_range": 1,
#     "signatures": [
#         "numbing Dan Dan noodles",
#         "cumin lamb skewers"
#     ],
#     "vibe": "cyberpunk, funky",
#     "environment": "vibrant pink neon lights",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the JSON output ...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the JSON output for The Morning Echo in Echo Park based on the provided description:
#
# {
#     "name": "The Morning Echo",
#     "location": "Echo Park",
#     "type": "elevated cafe",
#     "food_style": "brunch",
#     "rating": 4.0,
#     "price_range": 2,
#     "signatures": [
#         "ricotta pancakes with honeycomb butter"
#     ],
#     "vibe": "relaxed hipster",
#     "environment": "slow morning for people-watching beneath signature patio umbrellas",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Morning Echo",
#     "location": "Echo Park",
#     "type": "elevated cafe",
#     "food_style": "brunch",
#     "rating": 4.0,
#     "price_range": 2,
#     "signatures": [
#         "ricotta pancakes with honeycomb butter"
#     ],
#     "vibe": "relaxed hipster",
#     "environment": "slow morning for people-watching beneath signature patio umbrellas",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Sapphire Soul",
#     "location": "Inglewood",
#     "type": "Southern soul food fusion restaurant",
#     "food_style": "Southern soul food fusion",
#     "rating": 4.7,
#     "price_range": 2,
#     "signatures": [
#         "spicy hot-honey fried chicken",
#         "waffles"
#     ],
#     "vibe": "vibrant",
#     "environment": "soulful and welcoming",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the restaurant d...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the restaurant description converted to a structured JSON format based on the provided example:
#
# {
#   "name": "The Emerald Garden",
#   "location": "Culver City",
#   "type": "Vietnamese bistro",
#   "food_style": "lush, tropical escape",
#   "rating": 4.6,
#   "price_range": 4,
#   "signatures": [
#     "lemongrass branzino"
#   ],
#   "vibe": "refreshing, breezy",
#   "environment": "a tropical escape hidden in the city",
#   "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#   "name": "The Emerald Garden",
#   "location": "Culver City",
#   "type": "Vietnamese bistro",
#   "food_style": "lush, tropical escape",
#   "rating": 4.6,
#   "price_range": 4,
#   "signatures": [
#     "lemongrass branzino"
#   ],
#   "vibe": "refreshing, breezy",
#   "environment": "a tropical escape hidden in the city",
#   "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected `,` or `}` at line 13 column 5 [type=json_invalid, input_value='{\n    "name": "Salt & S...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# {
#     "name": "Salt & Sand",
#     "location": "Manhattan Beach",
#     "type": "casual-fine dining",
#     "food_style": "coastal Italian",
#     "rating": 4.3,
#     "price_range": 4,
#     "signatures": [
#         "uni linguine"
#     ],
#     "vibe": "upscale, breezy",
#     "environment": "beachside relaxation with culinary precision"
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Salt & Sand",
#     "location": "Manhattan Beach",
#     "type": "casual-fine dining",
#     "food_style": "coastal Italian",
#     "rating": 4.3,
#     "price_range": 4,
#     "signatures": [
#         "uni linguine"
#     ],
#     "vibe": "upscale, breezy",
#     "environment": "beachside relaxation with culinary precision",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Guerrero Kitchen",
#     "location": "Boyle Heights",
#     "type": "Oaxacan family eatery",
#     "food_style": "vibrant, community-focused",
#     "rating": 4.8,
#     "price_range": 1,
#     "signatures": [
#         "24-ingredient mole negro"
#     ],
#     "vibe": "colorful extension of a family home",
#     "environment": "a local treasure known for profound and complex flavors"
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Velvet Lounge",
#     "location": "Beverly Hills",
#     "type": "old-Hollywood Continental supper club",
#     "food_style": "nostalgic American",
#     "rating": 4.1,
#     "price_range": 3,
#     "signatures": [
#         "tableside steak tartare",
#         "stiff martinis"
#     ],
#     "vibe": "sultry, dim-lit nostalgia",
#     "environment": "plush booths in a timeless glamour setting",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the structured J...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the structured JSON output for Seoul Soul in Koreatown based on the provided description:
#
# {
#   "name": "Seoul Soul",
#   "location": "Koreatown",
#   "type": "Korean BBQ hotspot",
#   "food_style": "premium wagyu cuts",
#   "rating": 4.5,
#   "price_range": 4,
#   "signatures": [
#     "loud, rhythmic atmosphere",
#     "perfect starting point for a night out in one of the city's most active nightlife districts"
#   ],
#   "vibe": "high-energy industrial",
#   "environment": "combines premium wagyu cuts with a loud, rhythmic atmosphere",
#   "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#   "name": "Seoul Soul",
#   "location": "Koreatown",
#   "type": "Korean BBQ hotspot",
#   "food_style": "premium wagyu cuts",
#   "rating": 4.5,
#   "price_range": 4,
#   "signatures": [
#     "loud, rhythmic atmosphere",
#     "perfect starting point for a night out in one of the city's most active nightlife districts"
#   ],
#   "vibe": "high-energy industrial",
#   "environment": "combines premium wagyu cuts with a loud, rhythmic atmosphere",
#   "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Blue Fig",
#     "location": "Los Feliz",
#     "type": "bohemian and relaxed Eastern Mediterranean cafe",
#     "food_style": "hidden neighborhood sanctuary",
#     "rating": 4.4,
#     "price_range": 4,
#     "signatures": [
#         "airy, wood-fired pita",
#         "deeply smoky eggplant mutabbal"
#     ],
#     "vibe": "garden-like outdoor seating area",
#     "environment": "bohemian and relaxed",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Vinyl Bird",
#     "location": "Highland Park",
#     "type": "Fried Chicken shack",
#     "food_style": "Nashville-style fried chicken",
#     "rating": 4.2,
#     "price_range": 3,
#     "signatures": [
#         "Nashville-style seasoned fried chicken",
#         "honey-brushed biscuits"
#     ],
#     "vibe": "retro, vinyl-spinning",
#     "environment": "a space filled with the warm crackle of analog records",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the restaurant i...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the restaurant information converted to a well-defined JSON schema:
#
# {
#     "name": "The Obsidian Room",
#     "location": "Downtown LA",
#     "type": "Experimental Japanese omakase bar",
#     "food_style": "minimalist and dark-chic",
#     "rating": 4.9,
#     "price_range": 4,
#     "signatures": [
#         "innovative dry-aging fish program"
#     ],
#     "vibe": "hushed, focused environment",
#     "environment": "feels worlds away from the city streets",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Obsidian Room",
#     "location": "Downtown LA",
#     "type": "Experimental Japanese omakase bar",
#     "food_style": "minimalist and dark-chic",
#     "rating": 4.9,
#     "price_range": 4,
#     "signatures": [
#         "innovative dry-aging fish program"
#     ],
#     "vibe": "hushed, focused environment",
#     "environment": "feels worlds away from the city streets",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the restaurant i...relaxed weekend hangout', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the restaurant information converted to a well-defined JSON schema suitable for indexing and search, with dollar signs converted to an integer representing the number of dollar symbols:
#
# {
#     "name": "The Green Leaf",
#     "location": "Venice Beach",
#     "type": "plant-based gastropub",
#     "food_style": "plant-based",
#     "rating": 3.9,
#     "price_range": 3,
#     "signatures": [
#         "jackfruit \"carnitas\"",
#         "rotating list of local organic craft beers"
#     ],
#     "vibe": "earthy, sun-soaked",
#     "environment": "a staple for the health-conscious beach crowd looking for a relaxed weekend hangout.",
#     "shortcomings": []
# }
#
# The key details extract from the description are:
# - Name: The Green Leaf
# - Location: Venice Beach
# - Type: Plant-based gastropub
# - Food style: Plant-based
# - Rating: 3.9/5
# - Price range: $$$ (3 dollar signs, so price_range is set to 3)
# - Signatures: Jackfruit "carnitas", rotating list of local organic craft beers
# - Vibe: Earthy, sun-soaked
# - Environment: Staple for health-conscious beach crowd looking for relaxed weekend hangout
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Green Leaf",
#     "location": "Venice Beach",
#     "type": "plant-based gastropub",
#     "food_style": "plant-based",
#     "rating": 3.9,
#     "price_range": 3,
#     "signatures": [
#         "jackfruit \"carnitas\"",
#         "rotating list of local organic craft beers"
#     ],
#     "vibe": "earthy, sun-soaked",
#     "environment": "a staple for the health-conscious beach crowd looking for a relaxed weekend hangout.",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Copper Pot",
#     "location": "Pasadena",
#     "type": "Modern Indian dining room",
#     "food_style": "warm and sophisticated",
#     "rating": 4.7,
#     "price_range": 2,
#     "signatures": [
#         "butter chicken pot pie",
#         "deconstructed samosas"
#     ],
#     "vibe": "warm and sophisticated",
#     "environment": "elegant space defined by rich copper accents and soft amber lighting.",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# 20 out of 210 is done
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 2 validation errors for Restaurant
# food_style
#   Field required [type=missing, input_value={'name': 'The Rustic Oliv...u'], 'shortcomings': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# environment
#   Field required [type=missing, input_value={'name': 'The Rustic Oliv...u'], 'shortcomings': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# INVALID OUTPUT:
# {
#     "name": "The Rustic Olive",
#     "location": "Sherman Oaks",
#     "type": "Traditional Italian trattoria",
#     "vibe": "cozy and candlelit",
#     "rating": 4.4,
#     "price_range": 2,
#     "signatures": [
#         "handmade pappardelle with wild boar ragu"
#     ],
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#   "name": "The Rustic Olive",
#   "location": "Sherman Oaks",
#   "type": "Traditional Italian trattoria",
#   "food_style": "Traditional Italian cuisine",
#   "rating": 4.4,
#   "price_range": 2,
#   "signatures": [
#     "handmade pappardelle with wild boar ragu"
#   ],
#   "vibe": "cozy and candlelit",
#   "environment": "indoor",
#   "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected `,` or `}` at line 14 column 5 [type=json_invalid, input_value='{\n    "name": "Noche de...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# {
#     "name": "Noche de Luz",
#     "location": "Silver Lake",
#     "type": "Spanish Tapas wine bar",
#     "food_style": "small plates with big impact",
#     "rating": 4.5,
#     "price_range": 3,
#     "signatures": [
#         "crispy-bottomed paella",
#         "curated sherry list"
#     ],
#     "vibe": "sultry, dim-lit",
#     "environment": "hidden back patio with long, lingering evenings"
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Noche de Luz",
#     "location": "Silver Lake",
#     "type": "Spanish Tapas wine bar",
#     "food_style": "small plates with big impact",
#     "rating": 4.5,
#     "price_range": 3,
#     "signatures": [
#         "crispy-bottomed paella",
#         "curated sherry list"
#     ],
#     "vibe": "sultry, dim-lit",
#     "environment": "hidden back patio with long, lingering evenings",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the structured J...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the structured JSON output for The Silk Road based on the provided information:
#
# {
#     "name": "The Silk Road",
#     "location": "Glendale",
#     "type": "fine-dining establishment",
#     "food_style": "Persian",
#     "rating": 4.8,
#     "price_range": 2,
#     "signatures": [
#         "safron-infused Koobideh kabobs",
#         "herb-heavy stews"
#     ],
#     "vibe": "opulent and regal",
#     "environment": "a room adorned with intricate Persian carpets and crystal chandeliers",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Silk Road",
#     "location": "Glendale",
#     "type": "fine-dining establishment",
#     "food_style": "Persian",
#     "rating": 4.8,
#     "price_range": 2,
#     "signatures": [
#         "safron-infused Koobideh kabobs",
#         "herb-heavy stews"
#     ],
#     "vibe": "opulent and regal",
#     "environment": "a room adorned with intricate Persian carpets and crystal chandeliers",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the restaurant d...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the restaurant description converted into a well-defined JSON schema:
#
# {
#     "name": "Waffle & Wick",
#     "location": "Long Beach",
#     "type": "Breakfast & Brunch loft",
#     "food_style": "creative comfort food",
#     "rating": 4.1,
#     "price_range": 1,
#     "signatures": [
#         "chicken-and-waffle stacks",
#         "house-made infused syrups"
#     ],
#     "vibe": "energetic and modern",
#     "environment": "high-ceilinged space that feels bright and industrial",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Waffle & Wick",
#     "location": "Long Beach",
#     "type": "Breakfast & Brunch loft",
#     "food_style": "creative comfort food",
#     "rating": 4.1,
#     "price_range": 1,
#     "signatures": [
#         "chicken-and-waffle stacks",
#         "house-made infused syrups"
#     ],
#     "vibe": "energetic and modern",
#     "environment": "high-ceilinged space that feels bright and industrial",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the restaurant d...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the restaurant description converted into the requested JSON schema:
#
# {
#     "name": "The Golden Pagoda",
#     "location": "Chinatown",
#     "type": "Dim Sum parlor",
#     "food_style": "traditional Dim Sum",
#     "rating": 4.3,
#     "price_range": 3,
#     "signatures": [
#         "translucent shrimp har gow",
#         "steamed pork buns"
#     ],
#     "vibe": "bustling and traditional",
#     "environment": "a cornerstone of the neighborhood",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Golden Pagoda",
#     "location": "Chinatown",
#     "type": "Dim Sum parlor",
#     "food_style": "traditional Dim Sum",
#     "rating": 4.3,
#     "price_range": 3,
#     "signatures": [
#         "translucent shrimp har gow",
#         "steamed pork buns"
#     ],
#     "vibe": "bustling and traditional",
#     "environment": "a cornerstone of the neighborhood",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the restaurant d...mber of dollar symbols.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the restaurant description for Surfside Grill in Malibu converted into a structured JSON format:
#
# {
#     "name": "Surfside Grill",
#     "location": "Malibu",
#     "type": "rugged, oceanfront American Seafood shack",
#     "food_style": "overstuffed lobster rolls and casual, sandy-feet-welcome vibe",
#     "rating": 4.0,
#     "price_range": 2,
#     "signatures": [
#         "overstuffed lobster rolls"
#     ],
#     "vibe": "casual beachside",
#     "environment": "quintessential stop after a day on the Pacific Coast Highway",
#     "shortcomings": []
# }
#
# The dollar signs $$ for the price range have been converted to the integer 2 representing the number of dollar symbols.
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Surfside Grill",
#     "location": "Malibu",
#     "type": "rugged, oceanfront American Seafood shack",
#     "food_style": "overstuffed lobster rolls and casual, sandy-feet-welcome vibe",
#     "rating": 4.0,
#     "price_range": 2,
#     "signatures": [
#         "overstuffed lobster rolls"
#     ],
#     "vibe": "casual beachside",
#     "environment": "quintessential stop after a day on the Pacific Coast Highway",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Iron Skillet",
#     "location": "Compton",
#     "type": "Soul Food kitchen",
#     "food_style": "homestyle and welcoming",
#     "rating": 4.7,
#     "price_range": 3,
#     "signatures": [
#         "tender smothered pork chops",
#         "peach cobbler"
#     ],
#     "vibe": "homestyle and welcoming",
#     "environment": "a kitchen that tastes like a Sunday afternoon, with a humble, friendly dining room",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Neon Crane",
#     "location": "Westwood",
#     "type": "sushi fusion spot",
#     "food_style": "playful sushi fusion",
#     "rating": 4.2,
#     "price_range": 1,
#     "signatures": [
#         "spicy tuna crispy rice",
#         "volcano rolls"
#     ],
#     "vibe": "young, high-energy crowd",
#     "environment": "trendy, neon-lit, sleek, modern Tokyo lounge",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Thirsty Cactus",
#     "location": "North Hollywood",
#     "type": "festive Tex-Mex cantina",
#     "food_style": "Tex-Mex",
#     "rating": 3.8,
#     "price_range": 1,
#     "signatures": [
#         "oversized frozen margaritas",
#         "brisket tacos"
#     ],
#     "vibe": "festive and eclectic",
#     "environment": "colorful and loud backdrop for birthdays and celebrations",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Stone Hearth",
#     "location": "Topanga",
#     "type": "mystical and woodland New American eatery",
#     "food_style": "rustic, fire-driven New American cuisine",
#     "signature_dishes": ["foraged mushroom tart"],
#     "vibe": "mystical and woodland",
#     "environment": "a serene dining experience tucked away in the canyon where the sound of the wind in the trees is the only soundtrack you need",
#     "rating": 4.6,
#     "price_range": 3
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Spice Alchemist",
#     "location": "Alhambra",
#     "type": "Szechuan eatery",
#     "food_style": "vibrant and modern",
#     "rating": 4.5,
#     "price_range": 4,
#     "signatures": [
#         "numbing peppercorn chicken"
#     ],
#     "vibe": "pushes the boundaries of traditional heat",
#     "environment": "sleek, minimalist decor that balances the intensity of the food with a calm, clean aesthetic",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the information ...ortcomings": []\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the information from **Maritime Provisions** converted into a well-defined JSON schema suitable for indexing and search:
#
# ```json
# {
#   "name": "Maritime Provisions",
#   "location": "San Pedro",
#   "type": "wharf-style kitchen",
#   "food_style": "American Seafood",
#   "rating": 4.2,
#   "price_range": 1,
#   "signatures": [
#     "cracked crab platters",
#     "sourdough bread bowls"
#   ],
#   "vibe": "salty and industrial",
#   "environment": "a no-frills, high-quality experience by the docks",
#   "shortcomings": []
# }
# ```
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#   "name": "Maritime Provisions",
#   "location": "San Pedro",
#   "type": "wharf-style kitchen",
#   "food_style": "American Seafood",
#   "rating": 4.2,
#   "price_range": 1,
#   "signatures": [
#     "cracked crab platters",
#     "sourdough bread bowls"
#   ],
#   "vibe": "salty and industrial",
#   "environment": "a no-frills, high-quality experience by the docks",
#   "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Lavender Husk",
#     "location": "Abbot Kinney",
#     "type": "Modern Vegan bistro",
#     "food_style": "chic and airy",
#     "rating": 4.4,
#     "price_range": 3,
#     "signatures": [
#         "smoked beet tartare"
#     ],
#     "vibe": "sun-drenched space filled with hanging plants and light oak furniture",
#     "environment": "epitomizes the Venice lifestyle",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Little Sicily",
#     "location": "San Pedro",
#     "type": "Italian-American deli",
#     "food_style": "homestyle",
#     "rating": 4.6,
#     "price_range": 4,
#     "signatures": [
#         "Godfather sub",
#         "massive meatballs"
#     ],
#     "vibe": "homestyle and bustling",
#     "environment": "a space crowded with vintage family photos and the constant chatter of neighborhood regulars.",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the JSON output ...ance, and overall vibe.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the JSON output for the provided restaurant description:
#
# {
#     "name": "The Saffron Loom",
#     "location": "Tehrangeles (Westwood)",
#     "type": "elegant Persian tea house and grill",
#     "food_style": "Persian",
#     "rating": 4.7,
#     "price_range": 3,
#     "signatures": [
#         "tahdig - the coveted crispy rice",
#         "cherry-infused albaloo polo"
#     ],
#     "vibe": "sophisticated",
#     "environment": "a room draped in jewel-toned fabrics and copper lanterns"
# }
#
# This JSON output captures the key details from the restaurant description, including the name, location, type of establishment, cuisine style, rating, price range (as an integer count of dollar signs), signature dishes, ambiance, and overall vibe.
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Saffron Loom",
#     "location": "Tehrangeles (Westwood)",
#     "type": "elegant Persian tea house and grill",
#     "food_style": "Persian",
#     "rating": 4.7,
#     "price_range": 3,
#     "signatures": [
#         "tahdig - the coveted crispy rice",
#         "cherry-infused albaloo polo"
#     ],
#     "vibe": "sophisticated",
#     "environment": "a room draped in jewel-toned fabrics and copper lanterns"
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Cielito Lindo Lounge",
#     "location": "East LA",
#     "type": "festive and soulful Contemporary Mexican cantina",
#     "food_style": "Contemporary Mexican",
#     "rating": 4.3,
#     "price_range": 2,
#     "signatures": ["duck carnitas with blackberry mole"],
#     "vibe": "festive and soulful under a canopy of colorful papel picado",
#     "environment": "bridges the gap between old-school flavors and modern presentation",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the JSON-structu...ortcomings": []\n}\n```', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the JSON-structured output for The Brass Monkey based on the provided description:
#
# ```json
# {
#     "name": "The Brass Monkey",
#     "location": "Koreatown",
#     "type": "Korean-American gastropub",
#     "food_style": "late-night comfort",
#     "rating": 4.1,
#     "price_range": 4,
#     "signatures": [
#         "kimchi-topped poutine",
#         "bulgogi sliders"
#     ],
#     "vibe": "rowdy, neon-soaked",
#     "environment": "late-night karaoke setting",
#     "shortcomings": []
# }
# ```
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Brass Monkey",
#     "location": "Koreatown",
#     "type": "Korean-American gastropub",
#     "food_style": "late-night comfort",
#     "rating": 4.1,
#     "price_range": 4,
#     "signatures": [
#         "kimchi-topped poutine",
#         "bulgogi sliders"
#     ],
#     "vibe": "rowdy, neon-soaked",
#     "environment": "late-night karaoke setting",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# ...
#     "type": "sleek and modern Californian grill",
#     "food_style": "wood-fired pizzas and crispy Brussels sprouts with lemon marmalade",
#     "rating": 4.4,
#     "price_range": 2,
#     "signatures": [],
#     "vibe": "sophisticated glass-walled environment connecting diners to the scenic Sacramento River",
#     "environment": "",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the restaurant i...  "shortcomings": []\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the restaurant information converted to the JSON schema:
#
# {
#     "name": "Workshop Kitchen + Bar",
#     "location": "Palm Springs",
#     "style": "industrial and high-concept",
#     "cuisine": "New American",
#     "rating": 4.5,
#     "price_range": 4,
#     "menu": [
#         "wood-fired pizza",
#         "market-driven small plates"
#     ],
#     "vibe": "brutalist, concrete-heavy space that stands as a stark, chic contrast to the town's usual mid-century pastels.",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Workshop Kitchen + Bar",
#     "location": "Palm Springs",
#     "type": "industrial and high-concept",
#     "food_style": "New American",
#     "rating": 4.5,
#     "price_range": 4,
#     "signatures": [
#         "wood-fired pizza",
#         "market-driven small plates"
#     ],
#     "vibe": "brutalist, concrete-heavy space that stands as a stark, chic contrast to the town's usual mid-century pastels.",
#     "environment": "",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Chez Panisse",
#     "location": "Berkeley",
#     "type": "revolutionary and timeless Californian kitchen",
#     "food_style": "farm-to-table",
#     "rating": 4.8,
#     "price_range": 1,
#     "signatures": [],
#     "vibe": "warm, copper-lit sanctuary where every meal feels like a tribute to the soil and the season",
#     "environment": "providing a warm, copper-lit sanctuary where every meal feels like a tribute to the soil and the season",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# 200 out of 210 is done
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Neon Lotus",
#     "location": "Koreatown",
#     "type": "casual fine-dining establishment",
#     "food_style": "Korean fusion",
#     "rating": 4.7,
#     "price_range": 3,
#     "signatures": [
#         "Kimchi Carbonara"
#     ],
#     "vibe": "high-energy electric ambiance",
#     "environment": "neo-noir aesthetic with moody purple LED accents and sleek charcoal furniture",
#     "shortcomings": [
#         "music can get loud on weekends"
#     ]
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Saffron & Sage",
#     "location": "North Brand Boulevard in Glendale",
#     "decor": "intricate gold-leaf and plush velvet seating",
#     "type": "upscale Persian dining",
#     "food_style": "traditional Persian flavors",
#     "rating": 4.8,
#     "price_range": 2,
#     "signatures": [
#         "lamb koobideh",
#         "saffron-infused rice"
#     ],
#     "vibe": "quiet elegance",
#     "environment": "refined setting suited for celebratory dinners",
#     "reservation_note": "Friday night reservations usually require booking weeks in advance",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Cactus Flower",
#     "location": "Echo Park",
#     "type": "vegan Mexican bistro",
#     "food_style": "plant-based Mexican",
#     "rating": 4.2,
#     "price_range": 4,
#     "signatures": [
#         "jackfruit carnitas",
#         "house-made cashew crema"
#     ],
#     "vibe": "boho-chic",
#     "environment": "relaxed, sun-drenched space with hanging succulents and reclaimed wood tables",
#     "shortcomings": [
#         "intimate seating area means short wait during peak brunch rush"
#     ]
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the information ...ll customers"\n    ]\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the information about Iron Griddle in Torrance converted into a well-defined JSON schema suitable for indexing and search:
#
# {
#     "name": "Iron Griddle",
#     "location": "Torrance",
#     "type": "industrial-style Japanese BBQ house",
#     "food_style": "all-you-can-eat interactive format",
#     "rating": 4.5,
#     "price_range": 4,
#     "features": [
#         "Wagyu beef cuts in premium tier",
#         "bustling atmosphere for groups and families",
#         "heavy-duty ventilation systems at every table",
#         "high-energy venue",
#         "sophisticated Japanese BBQ house"
#     ],
#     "signature_items": [],
#     "environment": "exposed brick interior with high-grade ventilation",
#     "shortcomings": [
#         "can get quite smoky despite efficient staff",
#         "high-grade meat may be challenging to grill perfectly for all customers"
#     ]
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Iron Griddle",
#     "location": "Torrance",
#     "type": "industrial-style Japanese BBQ house",
#     "food_style": "all-you-can-eat interactive format",
#     "rating": 4.5,
#     "price_range": 4,
#     "signatures": [],
#     "vibe": null,
#     "environment": "exposed brick interior with high-grade ventilation",
#     "shortcomings": [
#         "can get quite smoky despite efficient staff",
#         "high-grade meat may be challenging to grill perfectly for all customers"
#     ]
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected value at line 1 column 1 [type=json_invalid, input_value='Here is the JSON schema ...ium location"\n    ]\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# Here is the JSON schema for The Salty Pelican:
#
# {
#     "name": "The Salty Pelican",
#     "location": "Santa Monica",
#     "type": "beachfront cafe",
#     "food_style": "casual",
#     "rating": 3.9,
#     "price_range": 1,
#     "signatures": [
#         "generous lobster rolls"
#     ],
#     "vibe": "nautical beachfront atmosphere, people-watching",
#     "environment": "sunny outdoor patio along the boardwalk",
#     "shortcomings": [
#         "slightly higher prices due to premium location"
#     ]
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Salty Pelican",
#     "location": "Santa Monica",
#     "type": "beachfront cafe",
#     "food_style": "casual",
#     "rating": 3.9,
#     "price_range": 1,
#     "signatures": [
#         "generous lobster rolls"
#     ],
#     "vibe": "nautical beachfront atmosphere, people-watching",
#     "environment": "sunny outdoor patio along the boardwalk",
#     "shortcomings": [
#         "slightly higher prices due to premium location"
#     ]
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Velvet Dragon",
#     "location": "Chinatown",
#     "type": "casual eatery",
#     "food_style": "Dim Sum",
#     "rating": 4.1,
#     "price_range": 1,
#     "signatures": [
#         "truffle-infused siu mai",
#         "charcoal custard buns"
#     ],
#     "vibe": "fast-paced and innovative",
#     "environment": "minimalist and social with communal tables",
#     "shortcomings": [
#         "lacks classic rolling cart experience"
#     ]
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
#   Invalid JSON: expected `,` or `}` at line 14 column 5 [type=json_invalid, input_value='{\n    "name": "Maple & ... garden seat"\n    ]\n}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
#
# INVALID OUTPUT:
# {
#     "name": "Maple & Moss",
#     "location": "Pasadena",
#     "type": "organic farm-to-table brunch cafe",
#     "food_style": "seasonal vegetarian and egg-centric brunch dishes",
#     "rating": 4.6,
#     "price_range": 4,
#     "signatures": [
#         "lemon-ricotta pancakes",
#         "seasonal vegetable frittatas"
#     ],
#     "vibe": "serene and light-filled escape",
#     "environment": "indoor garden with floor-to-ceiling windows"
#     "shortcomings": [
#        "highly popular on weekends, arriving early is essential to secure a coveted garden seat"
#     ]
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Maple & Moss",
#     "location": "Pasadena",
#     "type": "organic farm-to-table brunch cafe",
#     "food_style": "seasonal vegetarian and egg-centric brunch dishes",
#     "rating": 4.6,
#     "price_range": 4,
#     "signatures": [
#         "lemon-ricotta pancakes",
#         "seasonal vegetable frittatas"
#     ],
#     "vibe": "serene and light-filled escape",
#     "environment": "indoor garden with floor-to-ceiling windows",
#     "shortcomings": [
#        "highly popular on weekends, arriving early is essential to secure a coveted garden seat"
#     ]
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Taco Cloud",
#     "location": "Boyle Heights",
#     "type": "fast-food stand",
#     "food_style": "cloud-style fluffy flour tortillas",
#     "rating": 4.4,
#     "price_range": 3,
#     "signatures": [
#         "carne asada",
#         "Avocado Foam"
#     ],
#     "vibe": "no-frills and mostly outdoor-focused",
#     "environment": "bright yellow metal stools and a constant, hungry queue of locals",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "The Pasta Project",
#     "location": "Silver Lake",
#     "type": "Italian bistro",
#     "food_style": "artisan pasta",
#     "rating": 4.3,
#     "price_range": 3,
#     "signatures": [
#         "cacio e pepe"
#     ],
#     "vibe": "minimalist and intimate",
#     "environment": "open kitchen with artisan pasta rolling, transparent dining environment, trendy neighborhood hub",
#     "shortcomings": [
#         "seating can feel cramped during the evening rush"
#     ]
# }
# Tryna Append....................................................
# Outa Append....................................................
# LLM Output Initiated....................................................
# LLM Output done....................................................
# Entered Try....................................................
# Entered Except
#
# VALIDATION ERROR:
# 1 validation error for Restaurant
# environment
#   Field required [type=missing, input_value={'name': 'Blue Velvet', '...ht', 'shortcomings': []}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# INVALID OUTPUT:
# {
#     "name": "Blue Velvet",
#     "location": "West Hollywood",
#     "type": "American speakeasy and bistro",
#     "food_style": "classic American",
#     "rating": 4.5,
#     "price_range": 4,
#     "vibe": "moody and romantic",
#     "atmosphere": "dark leather booths, dimmed candlelight",
#     "special_features": "live jazz on Thursday nights",
#     "recommended_dishes": ["melt-in-your-mouth prime rib", "expertly balanced old-fashioned cocktails"],
#     "ambience": "upscale sanctuary",
#     "occasion": "sophisticated date night",
#     "shortcomings": []
# }
# Entered Try....................................................
# Validated....................................................
#
# REPAIRED OUTPUT:
# {
#     "name": "Blue Velvet",
#     "location": "West Hollywood",
#     "type": "American speakeasy and bistro",
#     "food_style": "classic American",
#     "rating": 4.5,
#     "price_range": 4,
#     "signatures": [
#         "melt-in-your-mouth prime rib",
#         "expertly balanced old-fashioned cocktails"
#     ],
#     "vibe": "moody and romantic",
#     "environment": "upscale sanctuary",
#     "shortcomings": []
# }
# Tryna Append....................................................
# Outa Append....................................................
# ALL DONE!!

# %% [markdown]
# Take a screenshot of the Python code, clearly showing your implementation and the output from Step 2. Name the screenshot `M1L1_structure_for_loop.jpg`.

# %% [markdown]
# ### Step 3: Save the list to a JSON file

# %% [markdown]
# You are almost there! First, print the 50th item in your structured_restaurant_lists.

# %%
### Your Code Here:
### Print the 50th item in the structured_restaurant_lists
print(structured_restaurant_lists[50])
# Out:
# {
#     "name": "The Copper Tandoor",
#     "location": "Studio City",
#     "type": "Modern Indian grill",
#     "food_style": "refined and glowing",
#     "rating": 4.6,
#     "price_range": 2,
#     "signatures": [
#         "truffle naan",
#         "lamb chops marinated in a secret yogurt-spice blend"
#     ],
#     "vibe": "upscale",
#     "environment": "dominated by a massive, open-fire clay oven and deep velvet booths",
#     "shortcomings": []
# }

# %% [markdown]
# Then, save your processed data to your folder by running the following code!

# %%
structured_restaurant_lists_json = [json.loads(response) for response in structured_restaurant_lists]

#For each item in the restaurant list, assign it with an itemId to be consistent with the one in the user review data:
for i, response in enumerate(structured_restaurant_lists_json):
    response['itemId'] = 1000001 + i
    structured_restaurant_lists_json[i] = response
    
filename = 'structured_restaurant_data.json'
with open(filename, 'w', encoding='utf-8') as f:
    json.dump(structured_restaurant_lists_json, f, indent=4)

# %% [markdown]
# You can download the saved JSON file to your local folder. Be sure to keep it in a safe location, as you will need it for future assignments.

# %% [markdown]
# ----

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# You have successfully applied GenAI tools to transform the unstructured text data into a well-structured JSON file!

# %% [markdown]
# ## Authors

# %% [markdown]
# [Jianping (Mike) Ye](https://www.linkedin.com/in/jianping-ye/)

# %% [markdown]
# <!--## Changelog
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2026-02-02|1|Jianping Ye|Create lab|
# |2026-02-09|2|Jojy John|ID Review|-->

# %% [markdown]
# Copyright IBM Corporation. All rights reserved.
